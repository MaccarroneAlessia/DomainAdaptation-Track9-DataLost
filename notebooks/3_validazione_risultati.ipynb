# %% [markdown]
# # Multi-source Domain Adaptation - Parte 3: Validazione Risultati
#
# **Gruppo:** DataLost - **Track 9**
#
# Questo notebook è dedicato all'analisi finale e all'interpretazione dei risultati prodotti dal modello `MultiSourceDANN` precedentemente addestrato.
#
# ## Obiettivi e Passaggi Suggeriti (Da Implementare)
#
# ### 1. Caricamento del Modello Addestrato e delle Feature Target
# - Ripristinare i pesi finali (migliori epoche) dal file `checkpoint.pth` (generato durante la fase di training nel notebook 2).
# - Utilizzare le feature `Kinetics-400` da 2048 dimensioni calcolate nel notebook 1, da usare come Validation/Test set del nostro dominio Target.
#
# ### 2. Valutazione Quantitativa (Metriche Classiche)
# - Calcolare l'**Accuracy (Top-1 e Top-5)** sullo spazio delle 11 classi condivise.
# - Estrarre i report completi contenenti **Precision, Recall e F1-Score** per ogni classe per identificare sbilanciamenti prestazionali (in particolare la classe sovrarappresentata `walk`).
#
# ### 3. Matrice di Confusione
# - Disegnare la matrice di confusione (Confusion Matrix) per valutare quali attività risultano visivamente simili per la rete. (Ad es., *shoot_ball* confuso con *shoot_bow*).
#
# ### 4. Analisi Spaziale (Visualizzazione T-SNE / UMAP)
# - Estrarre gli embedding da `512` dimensioni prodotti dall'Encoder subito prima della classificazione.
# - Proiettare questi embedding (da HMDB51, UCF101 e Kinetics-400) in un plot 2D utilizzando **T-SNE**.
# - Confrontare la proiezione T-SNE **Baseline (Senza Domain Adaptation)** vs **DANN (Con Domain Adaptation)**. Un modello di successo mostrerà i cluster dei domini perfettamente sovrapposti semanticamente.
#
# ### 5. Ablation Studies (Opzionale ma Professionale)
# - Valutazione delle performance utilizzando solo S1 (HMDB51) o solo S2 (UCF101).
# - Impatto del modulo GRL sull'accuratezza finale.
#
# ### 6. Conclusioni del Progetto
# - Riflessioni conclusive sui limiti dell'approccio UDA nel contesto video.
